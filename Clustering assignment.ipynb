# %% [markdown]
# ---
# ---
# - It is a bundle of many Machine Learning algorithms.
# - Only three lines of code is required to compare 20 ML models.
# - Pycaret is available for:
#     - Classification
#     - Regression
#     - Clustering
#
# ---
#
# 1. Tutorial on Pycaret **<a href="https://pycaret.readthedocs.io/en/latest/tutorials.html"> Click Here</a>**
#
# 2. Documentation on Pycaret-Clustering: **<a href="https://pycaret.readthedocs.io/en/latest/api/clustering.html"> Click Here </a>**
#
# ---

# %% [markdown]
# ### **(a) Install Pycaret**

# %%
# !pip install pycaret &> /dev/null
print ("Pycaret installed sucessfully!!")
# Out:
# Pycaret installed sucessfully!!

# %% [markdown]
# ### **(b) Get the version of the pycaret**

# %%
from pycaret.utils import version
version()
# Out:
# '3.3.2'

# %% [markdown]
# ---
#
# ---
# ### **1.1 Get the list of datasets available in pycaret (55)**

# %%
# kmean
from pycaret.datasets import get_data
dataSets = get_data('index')
# Out:
#                              Dataset    Data Types  \
# 0                            anomaly  Multivariate
# 1                             france  Multivariate
# 2                            germany  Multivariate
# 3                               bank  Multivariate
# 4                              blood  Multivariate
# 5                             cancer  Multivariate
# 6                             credit  Multivariate
# 7                           diabetes  Multivariate
# 8                    electrical_grid  Multivariate
# 9                           employee  Multivariate
# 10                             heart  Multivariate
# 11                     heart_disease  Multivariate
# 12                         hepatitis  Multivariate
# 13                            income  Multivariate
# 14                             juice  Multivariate
# 15                               nba  Multivariate
# 16                              wine  Multivariate
# 17                         telescope  Multivariate
# 18                           titanic  Multivariate
# 19  us_presidential_election_results  Multivariate
# 20                             glass  Multivariate
# 21                              iris  Multivariate
# 22                             poker  Multivariate
# 23                         questions  Multivariate
# 24                         satellite  Multivariate
# 25                               CTG  Multivariate
# 26                          asia_gdp  Multivariate
# 27                         elections  Multivariate
# 28                          facebook  Multivariate
# 29                               ipl  Multivariate
# 30                         jewellery  Multivariate
# 31                              mice  Multivariate
# 32                         migration  Multivariate
# 33                           perfume  Multivariate
# 34                           pokemon  Multivariate
# 35                        population  Multivariate
# 36                     public_health  Multivariate
# 37                             seeds  Multivariate
# 38                         wholesale  Multivariate
# 39                            tweets          Text
# 40                            amazon          Text
# 41                              kiva          Text
# 42                               spx          Text
# 43                         wikipedia          Text
# 44                        automobile  Multivariate
# 45                              bike  Multivariate
# 46                            boston  Multivariate
# 47                          concrete  Multivariate
# 48                           diamond  Multivariate
# 49                            energy  Multivariate
# 50                            forest  Multivariate
# 51                              gold  Multivariate
# 52                             house  Multivariate
# 53                         insurance  Multivariate
# 54                        parkinsons  Multivariate
# 55                           traffic  Multivariate
#
#                    Default Task Target Variable 1 Target Variable 2  \
# 0             Anomaly Detection               NaN               NaN
# 1       Association Rule Mining         InvoiceNo       Description
# 2       Association Rule Mining         InvoiceNo       Description
# 3       Classification (Binary)           deposit               NaN
# 4       Classification (Binary)             Class               NaN
# 5       Classification (Binary)             Class               NaN
# 6       Classification (Binary)           default               NaN
# 7       Classification (Binary)    Class variable               NaN
# 8       Classification (Binary)             stabf               NaN
# 9       Classification (Binary)              left               NaN
# 10      Classification (Binary)             DEATH               NaN
# 11      Classification (Binary)           Disease               NaN
# 12      Classification (Binary)             Class               NaN
# 13      Classification (Binary)       income >50K               NaN
# 14      Classification (Binary)          Purchase               NaN
# 15      Classification (Binary)       TARGET_5Yrs               NaN
# 16      Classification (Binary)              type               NaN
# 17      Classification (Binary)             Class               NaN
# 18      Classification (Binary)          Survived               NaN
# 19      Classification (Binary)      party_winner               NaN
# 20  Classification (Multiclass)              Type               NaN
# 21  Classification (Multiclass)           species               NaN
# 22  Classification (Multiclass)             CLASS               NaN
# 23  Classification (Multiclass)     Next_Question               NaN
# 24  Classification (Multiclass)             Class               NaN
# 25  Classification (Multiclass)               NSP               NaN
# 26                   Clustering               NaN               NaN
# 27                   Clustering               NaN               NaN
# 28                   Clustering               NaN               NaN
# 29                   Clustering               NaN               NaN
# 30                   Clustering               NaN               NaN
# 31                   Clustering               NaN               NaN
# 32                   Clustering               NaN               NaN
# 33                   Clustering               NaN               NaN
# 34                   Clustering               NaN               NaN
# 35                   Clustering               NaN               NaN
# 36                   Clustering               NaN               NaN
# 37                   Clustering               NaN               NaN
# 38                   Clustering               NaN               NaN
# 39                          NLP             tweet               NaN
# 40         NLP / Classification        reviewText               NaN
# 41         NLP / Classification                en               NaN
# 42             NLP / Regression              text               NaN
# 43         NLP / Classification              Text               NaN
# 44                   Regression             price               NaN
# 45                   Regression               cnt               NaN
# 46                   Regression              medv               NaN
# 47                   Regression          strength               NaN
# 48                   Regression             Price               NaN
# 49                   Regression      Heating Load      Cooling Load
# 50                   Regression              area               NaN
# 51                   Regression         Gold_T+22               NaN
# 52                   Regression         SalePrice               NaN
# 53                   Regression           charges               NaN
# 54                   Regression               PPE               NaN
# 55                   Regression    traffic_volume               NaN
#
#     # Instances  # Attributes Missing Values
# 0          1000            10              N
# 1          8557             8              N
# 2          9495             8              N
# 3         45211            17              N
# 4           748             5              N
# 5           683            10              N
# 6         24000            24              N
# 7           768             9              N
# 8         10000            14              N
# 9         14999            10              N
# 10          200            16              N
# 11          270            14              N
# 12          154            32              Y
# 13        32561            14              Y
# 14         1070            15              N
# 15         1340            21              N
# 16         6498            13              N
# 17        19020            11              N
# 18          891            11              Y
# 19          497             7              N
# 20          214            10              N
# 21          150             5              N
# 22       100000            11              N
# 23          499             4              N
# 24         6435            37              N
# 25         2129            40              Y
# 26           40            11              N
# 27         3195            54              Y
# 28         7050            12              N
# 29          153            25              N
# 30          505             4              N
# 31         1080            82              Y
# 32          233            12              N
# 33           20            29              N
# 34          800            13              Y
# 35          255            56              Y
# 36          224            21              N
# 37          210             7              N
# 38          440             8              N
# 39         8594             2              N
# 40        20000             2              N
# 41         6818             7              N
# 42          874             4              N
# 43          500             3              N
# 44          202            26              Y
# 45        17379            15              N
# 46          506            14              N
# 47         1030             9              N
# 48         6000             8              N
# 49          768            10              N
# 50          517            13              N
# 51         2558           121              N
# 52         1461            81              Y
# 53         1338             7              N
# 54         5875            22              N
# 55        48204             8              N

# %% [markdown]
# ---
# ### **1.2 Get the "jewellery" dataset**
# ---

# %%
jewelleryDataSet = get_data("jewellery")    # SN is 30
# Out:
#    Age  Income  SpendingScore       Savings
# 0   58   77769       0.791329   6559.829923
# 1   59   81799       0.791082   5417.661426
# 2   62   74751       0.702657   9258.992965
# 3   59   74373       0.765680   7346.334504
# 4   87   17760       0.348778  16869.507130

# %% [markdown]
# ---
# ### **1.3 Download the "jewellery" dataset to system**
# ---

# %%
jewelleryDataSet.to_csv("jewelleryDataSet.csv")
from google.colab import files

# %% [markdown]
#   ---
# ### **1.4 "Parameter settings"  for clustering model**
# ##### **Train/Test division, applying data pre-processing** {Sampling, Normalization, Transformation, PCA, Handaling of Outliers, Feature Selection}
# ---

# %%
from pycaret.clustering import *
kMeanClusteringParameters = setup(jewelleryDataSet)
# Re-run the code if any error occur
# Out:
# <style type="text/css">
# #T_5bf8a_row4_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_5bf8a" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_5bf8a_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_5bf8a_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_5bf8a_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_5bf8a_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_5bf8a_row0_col1" class="data row0 col1" >4157</td>
#     </tr>
#     <tr>
#       <th id="T_5bf8a_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_5bf8a_row1_col0" class="data row1 col0" >Original data shape</td>
#       <td id="T_5bf8a_row1_col1" class="data row1 col1" >(505, 4)</td>
#     </tr>
#     <tr>
#       <th id="T_5bf8a_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_5bf8a_row2_col0" class="data row2 col0" >Transformed data shape</td>
#       <td id="T_5bf8a_row2_col1" class="data row2 col1" >(505, 4)</td>
#     </tr>
#     <tr>
#       <th id="T_5bf8a_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_5bf8a_row3_col0" class="data row3 col0" >Numeric features</td>
#       <td id="T_5bf8a_row3_col1" class="data row3 col1" >4</td>
#     </tr>
#     <tr>
#       <th id="T_5bf8a_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_5bf8a_row4_col0" class="data row4 col0" >Preprocess</td>
#       <td id="T_5bf8a_row4_col1" class="data row4 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_5bf8a_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_5bf8a_row5_col0" class="data row5 col0" >Imputation type</td>
#       <td id="T_5bf8a_row5_col1" class="data row5 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_5bf8a_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_5bf8a_row6_col0" class="data row6 col0" >Numeric imputation</td>
#       <td id="T_5bf8a_row6_col1" class="data row6 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_5bf8a_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_5bf8a_row7_col0" class="data row7 col0" >Categorical imputation</td>
#       <td id="T_5bf8a_row7_col1" class="data row7 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_5bf8a_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_5bf8a_row8_col0" class="data row8 col0" >CPU Jobs</td>
#       <td id="T_5bf8a_row8_col1" class="data row8 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_5bf8a_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_5bf8a_row9_col0" class="data row9 col0" >Use GPU</td>
#       <td id="T_5bf8a_row9_col1" class="data row9 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_5bf8a_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_5bf8a_row10_col0" class="data row10 col0" >Log Experiment</td>
#       <td id="T_5bf8a_row10_col1" class="data row10 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_5bf8a_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_5bf8a_row11_col0" class="data row11 col0" >Experiment Name</td>
#       <td id="T_5bf8a_row11_col1" class="data row11 col1" >cluster-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_5bf8a_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_5bf8a_row12_col0" class="data row12 col0" >USI</td>
#       <td id="T_5bf8a_row12_col1" class="data row12 col1" >e035</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ---
# ### **1.5 Building "KMean" clustering model**
# ---

# %%
KMeanClusteringModel = create_model('kmeans', num_clusters=3)
# Out:
# <style type="text/css">
# </style>
# <table id="T_a11e9" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a11e9_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_a11e9_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_a11e9_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_a11e9_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_a11e9_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_a11e9_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a11e9_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_a11e9_row0_col0" class="data row0 col0" >0.7393</td>
#       <td id="T_a11e9_row0_col1" class="data row0 col1" >3567.5370</td>
#       <td id="T_a11e9_row0_col2" class="data row0 col2" >0.3435</td>
#       <td id="T_a11e9_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_a11e9_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_a11e9_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]

# %% [markdown]
# ---
# ### **1.6 Assign Model - "Assign the labels" to the dataset**
# ---

# %%
kMeanPrediction = assign_model(KMeanClusteringModel)
kMeanPrediction
# Out:
#      Age  Income  SpendingScore       Savings    Cluster
# 0     58   77769       0.791329   6559.830078  Cluster 2
# 1     59   81799       0.791082   5417.661621  Cluster 2
# 2     62   74751       0.702657   9258.993164  Cluster 2
# 3     59   74373       0.765680   7346.334473  Cluster 2
# 4     87   17760       0.348778  16869.507812  Cluster 0
# ..   ...     ...            ...           ...        ...
# 500   28  101206       0.387441  14936.775391  Cluster 1
# 501   93   19934       0.203140  17969.693359  Cluster 0
# 502   90   35297       0.355149  16091.402344  Cluster 0
# 503   91   20681       0.354679  18401.087891  Cluster 0
# 504   89   30267       0.289310  14386.351562  Cluster 0
#
# [505 rows x 5 columns]

# %% [markdown]
# ---
# ### **1.7 Clustering in "Three line of code"**
# ---

# %%
from pycaret.clustering import *

kMeanClusteringParameters = setup(jewelleryDataSet, verbose=False)
KMeanClusteringModel = create_model('kmeans', num_clusters=3)
kMeanPrediction = assign_model(KMeanClusteringModel)
kMeanPrediction
# Out:
# <style type="text/css">
# </style>
# <table id="T_32fb0" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_32fb0_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_32fb0_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_32fb0_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_32fb0_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_32fb0_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_32fb0_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_32fb0_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_32fb0_row0_col0" class="data row0 col0" >0.7393</td>
#       <td id="T_32fb0_row0_col1" class="data row0 col1" >3567.5370</td>
#       <td id="T_32fb0_row0_col2" class="data row0 col2" >0.3435</td>
#       <td id="T_32fb0_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_32fb0_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_32fb0_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]
#      Age  Income  SpendingScore       Savings    Cluster
# 0     58   77769       0.791329   6559.830078  Cluster 0
# 1     59   81799       0.791082   5417.661621  Cluster 0
# 2     62   74751       0.702657   9258.993164  Cluster 0
# 3     59   74373       0.765680   7346.334473  Cluster 0
# 4     87   17760       0.348778  16869.507812  Cluster 1
# ..   ...     ...            ...           ...        ...
# 500   28  101206       0.387441  14936.775391  Cluster 2
# 501   93   19934       0.203140  17969.693359  Cluster 1
# 502   90   35297       0.355149  16091.402344  Cluster 1
# 503   91   20681       0.354679  18401.087891  Cluster 1
# 504   89   30267       0.289310  14386.351562  Cluster 1
#
# [505 rows x 5 columns]

# %% [markdown]
# ---
# ### **1.8 "Saving" the result**
# ---

# %%
kMeanPrediction.to_csv("KMeanResult.csv")
print("Result file save sucessfully!!")
# Out:
# Result file save sucessfully!!

# %% [markdown]
# ---
# ### **1.9 Download the "result file" to user local system**
# ---

# %%
from google.colab import files

# %% [markdown]
# ---
# # **2. Clustering: Saving and Loading the Model**
# ---
# ### **2.1 Save the "trained model"**
# ---

# %%
x = save_model(KMeanClusteringModel, 'kMeanClusteringModelFile')
# .pkl file is model file
# Out:
# Transformation Pipeline and Model Successfully Saved

# %% [markdown]
# ---
# ### **2.2 Download the "trained model**
# ---

# %%
from google.colab import files
#files.download('kMeanClusteringModelFile.pkl')      # Uncomment this line

# %% [markdown]
# ---
# ### **2.3 Load the model**
# ---
# ##### Use it, while working on **"Anaconda/Jupyter notebook"** on local machine

# %%
# to load model so that we can use it
KMeanClusteringModel1 = load_model('kMeanClusteringModelFile')
# Out:
# Transformation Pipeline and Model Successfully Loaded

# %% [markdown]
# ---
# ### **2.4 Upload and Load the trained model to "Colab Environment"**
# ---
# ##### **Upload the trained model**

# %%
from google.colab import files
#files.upload()                     # Uncomment this line

# %% [markdown]
# ##### **Load the trained model**

# %%
#KMeanClusteringModel1 = load_model('kMeanClusteringModelFile (1)')

# %% [markdown]
# ---
# # **3. Clustering: Cluster the new dataset (Unseen Data)**
# ---
# ### **3.1 Select some data or upload user dataset file**

# %%
# Select top 10 rows
newData = get_data("jewellery").iloc[:10]
# Out:
#    Age  Income  SpendingScore       Savings
# 0   58   77769       0.791329   6559.829923
# 1   59   81799       0.791082   5417.661426
# 2   62   74751       0.702657   9258.992965
# 3   59   74373       0.765680   7346.334504
# 4   87   17760       0.348778  16869.507130

# %% [markdown]
# ---
# ### **3.2 Make prediction on the new dataset (Unseen Data)**
# ---

# %%
newPredictions = predict_model(KMeanClusteringModel, data = newData)
newPredictions
# 2 paramters: model & new data
# Out:
#     Age    Income  SpendingScore       Savings    Cluster
# 0  58.0   77769.0       0.791329   6559.829923  Cluster 0
# 1  59.0   81799.0       0.791082   5417.661426  Cluster 0
# 2  62.0   74751.0       0.702657   9258.992965  Cluster 0
# 3  59.0   74373.0       0.765680   7346.334504  Cluster 0
# 4  87.0   17760.0       0.348778  16869.507130  Cluster 1
# 5  29.0  131578.0       0.847034   3535.514352  Cluster 2
# 6  54.0   76500.0       0.785198   6878.884249  Cluster 0
# 7  87.0   42592.0       0.355290  18086.287158  Cluster 1
# 8  83.0   34384.0       0.324719  14783.379086  Cluster 1
# 9  84.0   27693.0       0.367063  17879.558906  Cluster 1

# %% [markdown]
# ---
# ### **3.3 Save the prediction result to csv**
# ---

# %%
newPredictions.to_csv("NewPredictions.csv")
print("Result file save sucessfully!!")
# Out:
# Result file save sucessfully!!

# %% [markdown]
# ---
# # **4. Clustering: Ploting the Cluster**
# ---
# ```
# - Cluster PCA Plot (2d)          'cluster'
# - Cluster TSnE (3d)              'tsne'
# - Elbow Plot                     'elbow'
# - Silhouette Plot                'silhouette'
# - Distance Plot                  'distance'
# - Distribution Plot              'distribution'
# ```

# %% [markdown]
# ---
# ### **4.1 Evaluate Cluster Model**
# ---

# %%
evaluate_model(KMeanClusteringModel)
# pass model ka naam

# cluster t-SNE 3d is most imp
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Pipeline Plot', 'pipelin…

# %% [markdown]
# ---
# ### **4.2 2D-plot for Cluster**
# ---

# %%
plot_model(KMeanClusteringModel, plot='cluster')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="d010c2aa-4fb7-4b35-bb0d-62bab3e7ba6c" class="plotly-graph-div" style="height:600px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d010c2aa-4fb7-4b35-bb0d-62bab3e7ba6c")) {                    Plotly.newPlot(                        "d010c2aa-4fb7-4b35-bb0d-62bab3e7ba6c",                        [{"customdata":[[58],[60],[56],[60],[58],[56],[64],[63],[62],[59],[67],[58],[58],[57],[66],[64],[59],[68],[61],[64],[63],[55],[57],[57],[61],[59],[55],[58],[53],[61],[62],[60],[65],[60],[63],[56],[58],[62],[56],[59],[65],[62],[59],[59],[64],[62],[61],[56],[62],[60],[62],[64],[63],[58],[62],[59],[66],[59],[29],[58],[58],[55],[51],[57],[61],[60],[64],[65],[59],[58],[63],[61],[68],[59],[61],[63],[58],[62],[60],[62],[65],[59],[65],[58],[61],[66],[56],[62],[58],[56],[56],[61],[56],[61],[59],[62],[59],[59],[59],[57],[34],[59],[67],[61],[63],[56],[59],[58],[61],[55],[59],[59],[60],[60],[67],[57],[67],[64],[57],[53],[61],[61],[57],[58],[55],[55],[59],[58],[61],[59],[60],[53],[62],[55],[66],[64],[61],[59],[56],[62],[57],[66],[58],[64],[59],[61],[62],[59],[63],[61],[54],[56],[63],[59],[55],[57],[58],[60],[58]],"hovertemplate":"Cluster=Cluster 0\u003cbr\u003ePCA1=%{x}\u003cbr\u003ePCA2=%{y}\u003cbr\u003eFeature=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Cluster 0","marker":{"color":"#636efa","opacity":0.5,"symbol":"circle"},"mode":"markers","name":"Cluster 0","orientation":"v","showlegend":true,"x":[2555.7842237303444,-7740.904886148212,-15159.901907030271,-9955.598990292232,5073.487342754962,-7927.279401739005,-10817.514887710631,-182.87509914870532,-12401.01261323433,384.48864417494406,-15876.014206199567,2392.9514015408095,-4856.160273050595,-9604.976111586086,-3578.641169860194,3594.042431937768,-5713.304473394478,2456.114930263724,-4025.5345829792072,1223.3332868105272,-18377.08090902117,-1254.7960958097474,1380.9095889215475,-5506.504771609416,-1867.5011781843575,277.31943945234957,871.0561288829986,8122.
                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"Cluster=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Cluster 0","marker":{"color":"#636efa","opacity":0.7,"pattern":{"shape":""}},"name":"Cluster 0","offsetgroup":"Cluster 0","orientation":"v","showlegend":true,"x":["Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0"],"xaxis":"x","yaxis":"y","type":"histogram"},{"alignmentgroup":"True","customdata":[[58.0,77769.0,0.7913287878036499,6559.830078125],[60.0,67491.0,0.8466184735298157,7180.7138671875],[56.0,60059.0,0.7275840044021606,7166.8583984375],[60.0,65340.0,0.7316485047340393,8354.1962890625],[58.0,80278.0,0.8233590126037598,6335.978515625],[56.0,67274.0,0.7798516750335693,6652.39111328125],[64.0,64331.0,0.7571277618408203,5815.66015625],[63.0,75078.0,0.7831591367721558,7468.85107421875],[62.0,62747.0,0.7705945372581482,5852.326171875],[59.0,75505.0,0.7682786583900452,5006.52880859375],[67.0,59243.0,0.7436599731445312,5446.5576171875],[58.0,77559.0,0.7122963666915894,5742.5244140625],[58.0,70272.0,0.8229596018791199,5290.0869140625],[57.0,65608.0,0.7662312984466553,6904.318359375],[66.0,71672.0,0.7538892030715942,7387.83544921875],[64.0,78801.0,0.7403674721717834,6420.94384765625],[59.0,69460.0,0.7527238130569458,6101.3720703125],[68.0,77648.0,0.7965446710586548,6190.8642578125],[61.0,71171.0,0.721080482006073,6457.79052734375],[64.0,76410.0,0.7756041884422302,6135.30810546875],[63.0,56875.0,0.7622805833816528,7837.2333984375],[55.0,73895.0,0.7471254467964172,5563.90673828125],[57.0,76573.0,0.84059906005859 ...

# %% [markdown]
# ---
# ### **4.7 Distance Plot**
# ---

# %%
plot_model(KMeanClusteringModel, plot = 'distance') # Rerun the code

# %% [markdown]
# ---
# # **5. Compelete Code for Clustering (KMean)**
# ---
# ### **5.1 For Cluster = 3, 4, 5, 6**

# %%
from pycaret.datasets import get_data
from pycaret.clustering import *

jewelleryDataSet = get_data('jewellery', verbose=False)
setup(data = jewelleryDataSet, verbose=False)

print("For Cluster = 3")
x = create_model('kmeans', num_clusters = 3)

print("For Cluster = 4")
x = create_model('kmeans', num_clusters = 4)

print("For Cluster = 5")
x = create_model('kmeans', num_clusters = 5)

print("For Cluster = 6")
x = create_model('kmeans', num_clusters = 6)
# Out:
# For Cluster = 3
# <style type="text/css">
# </style>
# <table id="T_ed41e" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ed41e_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_ed41e_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_ed41e_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_ed41e_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_ed41e_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_ed41e_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ed41e_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_ed41e_row0_col0" class="data row0 col0" >0.7393</td>
#       <td id="T_ed41e_row0_col1" class="data row0 col1" >3567.5370</td>
#       <td id="T_ed41e_row0_col2" class="data row0 col2" >0.3435</td>
#       <td id="T_ed41e_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_ed41e_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_ed41e_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]
# For Cluster = 4
# <style type="text/css">
# </style>
# <table id="T_dada8" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_dada8_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_dada8_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_dada8_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_dada8_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_dada8_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_dada8_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_dada8_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_dada8_row0_col0" class="data row0 col0" >0.7207</td>
#       <td id="T_dada8_row0_col1" class="data row0 col1" >5011.8115</td>
#       <td id="T_dada8_row0_col2" class="data row0 col2" >0.4114</td>
#       <td id="T_dada8_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_dada8_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_dada8_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]
# For Cluster = 5
# <style type="text/css">
# </style>
# <table id="T_b45ac" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b45ac_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_b45ac_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_b45ac_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_b45ac_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_b45ac_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_b45ac_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b45ac_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_b45ac_row0_col0" class="data row0 col0" >0.6784</td>
#       <td id="T_b45ac_row0_col1" class="data row0 col1" >4684.5663</td>
#       <td id="T_b45ac_row0_col2" class="data row0 col2" >0.4552</td>
#       <td id="T_b45ac_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_b45ac_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_b45ac_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]
# For Cluster = 6
# <style type="text/css">
# </style>
# <table id="T_237dc" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_237dc_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_237dc_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_237dc_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_237dc_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_237dc_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_237dc_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_237dc_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_237dc_row0_col0" class="data row0 col0" >0.5784</td>
#       <td id="T_237dc_row0_col1" class="data row0 col1" >4805.1793</td>
#       <td id="T_237dc_row0_col2" class="data row0 col2" >0.5696</td>
#       <td id="T_237dc_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_237dc_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_237dc_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]

# %% [markdown]
# ---
# ### **5.2 Other Clustering Algorithms**
# ---
# ```
# - K-Means clustering                 'kmeans'
# - Affinity Propagation               'ap'
# - Mean shift clustering              'meanshift'
# - Spectral Clustering                'sc'
# - Agglomerative/Hierarichal Clustering           'hclust'
# - Density-Based Spatial Clustering   'dbscan'
# - OPTICS Clustering                  'optics'
# - Birch Clustering                   'birch'
# - K-Modes clustering                 'kmodes'
# ```

# %% [markdown]
# ---
# # **6. Clustering: Apply "Data Preprocessing"**
# ---
# ### **Read the Dataset**

# %%
from pycaret.clustering import *
from pycaret.datasets import get_data

jewelleryDataSet = get_data('jewellery')
# Out:
#    Age  Income  SpendingScore       Savings
# 0   58   77769       0.791329   6559.829923
# 1   59   81799       0.791082   5417.661426
# 2   62   74751       0.702657   9258.992965
# 3   59   74373       0.765680   7346.334504
# 4   87   17760       0.348778  16869.507130

# %% [markdown]
# ---
# ### **6.1 Model Performance using "Normalization"**
# ---
# ### **6.1.1 Elbow Plot**

# %%
setup(data = jewelleryDataSet, normalize = True, normalize_method = 'zscore', verbose=False)
x = create_model('kmeans')
plot_model(x, plot = 'elbow')
# Out:
# <style type="text/css">
# </style>
# <table id="T_3c155" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_3c155_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_3c155_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_3c155_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_3c155_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_3c155_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_3c155_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_3c155_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_3c155_row0_col0" class="data row0 col0" >0.7581</td>
#       <td id="T_3c155_row0_col1" class="data row0 col1" >1611.2647</td>
#       <td id="T_3c155_row0_col2" class="data row0 col2" >0.3743</td>
#       <td id="T_3c155_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_3c155_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_3c155_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]

# %% [markdown]
# ---
# ### **6.1.2 Evaluation parameters for Cluster = 3, 4, 5, 6**
# ---

# %%
setup(data = jewelleryDataSet, normalize = True, normalize_method = 'zscore', verbose=False)
# run for different clusters to get maximum silhouette score:

print("For Cluster = 3")
x = create_model('kmeans', num_clusters = 3)

print("For Cluster = 4")
x = create_model('kmeans', num_clusters = 4)

print("For Cluster = 5")
x = create_model('kmeans', num_clusters = 5)

print("For Cluster = 6")
x = create_model('kmeans', num_clusters = 6)

# max at 5
# Out:
# For Cluster = 3
# <style type="text/css">
# </style>
# <table id="T_f12fe" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f12fe_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_f12fe_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_f12fe_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_f12fe_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_f12fe_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_f12fe_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f12fe_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_f12fe_row0_col0" class="data row0 col0" >0.6963</td>
#       <td id="T_f12fe_row0_col1" class="data row0 col1" >1066.5812</td>
#       <td id="T_f12fe_row0_col2" class="data row0 col2" >0.5258</td>
#       <td id="T_f12fe_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_f12fe_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_f12fe_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]
# For Cluster = 4
# <style type="text/css">
# </style>
# <table id="T_183d8" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_183d8_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_183d8_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_183d8_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_183d8_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_183d8_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_183d8_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_183d8_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_183d8_row0_col0" class="data row0 col0" >0.7325</td>
#       <td id="T_183d8_row0_col1" class="data row0 col1" >1122.4249</td>
#       <td id="T_183d8_row0_col2" class="data row0 col2" >0.3947</td>
#       <td id="T_183d8_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_183d8_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_183d8_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]
# For Cluster = 5
# <style type="text/css">
# </style>
# <table id="T_4471a" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_4471a_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_4471a_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_4471a_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_4471a_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_4471a_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_4471a_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_4471a_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_4471a_row0_col0" class="data row0 col0" >0.8049</td>
#       <td id="T_4471a_row0_col1" class="data row0 col1" >3671.3580</td>
#       <td id="T_4471a_row0_col2" class="data row0 col2" >0.2762</td>
#       <td id="T_4471a_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_4471a_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_4471a_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]
# For Cluster = 6
# <style type="text/css">
# </style>
# <table id="T_85885" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_85885_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_85885_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_85885_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_85885_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_85885_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_85885_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_85885_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_85885_row0_col0" class="data row0 col0" >0.6310</td>
#       <td id="T_85885_row0_col1" class="data row0 col1" >3194.7876</td>
#       <td id="T_85885_row0_col2" class="data row0 col2" >0.7141</td>
#       <td id="T_85885_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_85885_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_85885_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]

# %% [markdown]
# ---
# ### **6.1.3 3D Plot for Cluster = 5**
# ---

# %%
setup(data = jewelleryDataSet, normalize = True, normalize_method = 'zscore', verbose=False)
x = create_model('kmeans', num_clusters = 5)
plot_model(x, plot = 'tsne')
# Out:
# <style type="text/css">
# </style>
# <table id="T_81227" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_81227_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_81227_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_81227_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_81227_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_81227_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_81227_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_81227_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_81227_row0_col0" class="data row0 col0" >0.8049</td>
#       <td id="T_81227_row0_col1" class="data row0 col1" >3671.3580</td>
#       <td id="T_81227_row0_col2" class="data row0 col2" >0.2762</td>
#       <td id="T_81227_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_81227_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_81227_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="315860ca-f23f-4580-9567-9ab02851a1e4" class="plotly-graph-div" style="height:800px; width:900px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("315860ca-f23f-4580-9567-9ab02851a1e4")) {                    Plotly.newPlot(                        "315860ca-f23f-4580-9567-9ab02851a1e4",                        [{"customdata":[[58],[55],[60],[56],[60],[58],[56],[64],[63],[62],[59],[67],[58],[58],[57],[66],[64],[59],[68],[61],[64],[63],[55],[57],[57],[61],[58],[59],[53],[59],[62],[60],[65],[60],[63],[56],[58],[62],[56],[59],[65],[62],[59],[66],[64],[62],[61],[56],[62],[60],[62],[64],[63],[58],[62],[61],[59],[59],[58],[55],[51],[57],[61],[60],[64],[65],[59],[58],[63],[61],[59],[56],[61],[63],[58],[62],[60],[62],[65],[59],[65],[58],[61],[66],[58],[68],[58],[67],[56],[61],[56],[61],[59],[62],[59],[59],[59],[57],[59],[61],[62],[67],[56],[59],[58],[61],[55],[59],[59],[60],[60],[67],[57],[56],[63],[64],[57],[60],[61],[61],[57],[64],[55],[59],[58],[58],[59],[53],[53],[59],[63],[55],[62],[61],[59],[55],[56],[57],[66],[66],[59],[59],[56],[61],[61],[63],[58],[62],[58],[55],[58],[60],[61],[57],[54],[62],[64]],"hovertemplate":"Cluster=Cluster 0\u003cbr\u003e0=%{x}\u003cbr\u003e1=%{y}\u003cbr\u003e2=%{z}\u003cbr\u003eFeature=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Cluster 0","marker":{"color":"#636efa","opacity":0.7,"symbol":"circle"},"mode":"markers","name":"Cluster 0","scene":"scene","showlegend":true,"x":
_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]
# For Cluster = 5
# <style type="text/css">
# </style>
# <table id="T_db7a5" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_db7a5_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_db7a5_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_db7a5_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_db7a5_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_db7a5_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_db7a5_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_db7a5_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_db7a5_row0_col0" class="data row0 col0" >0.8063</td>
#       <td id="T_db7a5_row0_col1" class="data row0 col1" >3503.4024</td>
#       <td id="T_db7a5_row0_col2" class="data row0 col2" >0.2748</td>
#       <td id="T_db7a5_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_db7a5_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_db7a5_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]
# For Cluster = 6
# <style type="text/css">
# </style>
# <table id="T_1b34b" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_1b34b_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_1b34b_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_1b34b_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_1b34b_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_1b34b_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_1b34b_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_1b34b_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_1b34b_row0_col0" class="data row0 col0" >0.6171</td>
#       <td id="T_1b34b_row0_col1" class="data row0 col1" >2980.5603</td>
#       <td id="T_1b34b_row0_col2" class="data row0 col2" >0.7357</td>
#       <td id="T_1b34b_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_1b34b_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_1b34b_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]

# %% [markdown]
# ---
# ### **6.5 Model Performance using "Transformation" + "Normalization" + "PCA"**
# ---
# ### **6.5.1 Elbow Plot**

# %%
setup(data = jewelleryDataSet, transformation = True, normalize = True, pca = True,
      normalize_method = 'zscore', transformation_method = 'yeo-johnson',
      pca_method = 'linear', verbose=False)
x = create_model('kmeans')
plot_model(x, plot = 'elbow')
# Out:
# <style type="text/css">
# </style>
# <table id="T_177d2" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_177d2_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_177d2_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_177d2_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_177d2_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_177d2_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_177d2_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_177d2_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_177d2_row0_col0" class="data row0 col0" >0.7544</td>
#       <td id="T_177d2_row0_col1" class="data row0 col1" >1467.4682</td>
#       <td id="T_177d2_row0_col2" class="data row0 col2" >0.3868</td>
#       <td id="T_177d2_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_177d2_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_177d2_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]

# %% [markdown]
# ---
# ### **6.5.2 Evaluation parameters for Cluster = 3, 4, 5, 6**
# ---

# %%
setup(data = jewelleryDataSet, transformation = True, normalize = True, pca = True,
      normalize_method = 'zscore',
      transformation_method = 'yeo-johnson',
      pca_method = 'linear', verbose=False)

print("For Cluster = 3")
x = create_model('kmeans', num_clusters = 3)

print("For Cluster = 4")
x = create_model('kmeans', num_clusters = 4)

print("For Cluster = 5")
x = create_model('kmeans', num_clusters = 5)

print("For Cluster = 6")
x = create_model('kmeans', num_clusters = 6)
# Out:
# For Cluster = 3
# <style type="text/css">
# </style>
# <table id="T_fafc4" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_fafc4_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_fafc4_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_fafc4_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_fafc4_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_fafc4_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_fafc4_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_fafc4_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_fafc4_row0_col0" class="data row0 col0" >0.6912</td>
#       <td id="T_fafc4_row0_col1" class="data row0 col1" >1016.4677</td>
#       <td id="T_fafc4_row0_col2" class="data row0 col2" >0.5410</td>
#       <td id="T_fafc4_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_fafc4_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_fafc4_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]
# For Cluster = 4
# <style type="text/css">
# </style>
# <table id="T_78c70" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_78c70_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_78c70_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_78c70_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_78c70_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_78c70_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_78c70_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_78c70_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_78c70_row0_col0" class="data row0 col0" >0.7544</td>
#       <td id="T_78c70_row0_col1" class="data row0 col1" >1467.4682</td>
#       <td id="T_78c70_row0_col2" class="data row0 col2" >0.3868</td>
#       <td id="T_78c70_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_78c70_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_78c70_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]
# For Cluster = 5
# <style type="text/css">
# </style>
# <table id="T_d8a50" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d8a50_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_d8a50_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_d8a50_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_d8a50_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_d8a50_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_d8a50_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d8a50_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_d8a50_row0_col0" class="data row0 col0" >0.8063</td>
#       <td id="T_d8a50_row0_col1" class="data row0 col1" >3503.4024</td>
#       <td id="T_d8a50_row0_col2" class="data row0 col2" >0.2748</td>
#       <td id="T_d8a50_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_d8a50_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_d8a50_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]
# For Cluster = 6
# <style type="text/css">
# </style>
# <table id="T_79c86" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_79c86_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_79c86_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_79c86_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_79c86_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_79c86_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_79c86_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_79c86_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_79c86_row0_col0" class="data row0 col0" >0.6590</td>
#       <td id="T_79c86_row0_col1" class="data row0 col1" >2978.8578</td>
#       <td id="T_79c86_row0_col2" class="data row0 col2" >0.7652</td>
#       <td id="T_79c86_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_79c86_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_79c86_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]

# %% [markdown]
# ---
# # **7. Other Clustering Techniques**
# ---
# ```
# K-Means clustering                 'kmeans'
# Affinity Propagation               'ap'
# Mean shift clustering              'meanshift'
# Spectral Clustering                'sc'
# Agglomerative Clustering           'hclust'
# Density-Based Spatial Clustering   'dbscan'
# OPTICS Clustering                  'optics'
# Birch Clustering                   'birch'
# K-Modes clustering                 'kmodes'
# ```

# %% [markdown]
# ---
# ### **7.1 Buildign Agglomerative (Hierarchical) clustering model**
# ---

# %%
from pycaret.datasets import get_data
from pycaret.clustering import *

jewelleryDataSet = get_data('jewellery', verbose=False)
setup(data = jewelleryDataSet, verbose=False)

x = create_model('hclust')    #Agglomerative
plot_model(x, plot = 'elbow')

# here we did not provide no of clusters
# no of clust=3
# Out:
# <style type="text/css">
# </style>
# <table id="T_dc81f" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_dc81f_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_dc81f_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_dc81f_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_dc81f_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_dc81f_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_dc81f_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_dc81f_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_dc81f_row0_col0" class="data row0 col0" >0.7060</td>
#       <td id="T_dc81f_row0_col1" class="data row0 col1" >4827.2243</td>
#       <td id="T_dc81f_row0_col2" class="data row0 col2" >0.4339</td>
#       <td id="T_dc81f_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_dc81f_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_dc81f_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]

# %% [markdown]
# ---
# ### **7.1.1 Assign Model - "Assign the labels" to the dataset**
# ---

# %%
hierarchicalModel = create_model('hclust', num_clusters=3)
hierarchicalModelPrediction = assign_model(hierarchicalModel)
hierarchicalModelPrediction
# Out:
# <style type="text/css">
# </style>
# <table id="T_e073c" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e073c_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_e073c_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_e073c_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_e073c_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_e073c_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_e073c_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e073c_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_e073c_row0_col0" class="data row0 col0" >0.7391</td>
#       <td id="T_e073c_row0_col1" class="data row0 col1" >3542.6251</td>
#       <td id="T_e073c_row0_col2" class="data row0 col2" >0.3407</td>
#       <td id="T_e073c_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_e073c_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_e073c_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]
#      Age  Income  SpendingScore       Savings    Cluster
# 0     58   77769       0.791329   6559.830078  Cluster 2
# 1     59   81799       0.791082   5417.661621  Cluster 2
# 2     62   74751       0.702657   9258.993164  Cluster 2
# 3     59   74373       0.765680   7346.334473  Cluster 2
# 4     87   17760       0.348778  16869.507812  Cluster 1
# ..   ...     ...            ...           ...        ...
# 500   28  101206       0.387441  14936.775391  Cluster 0
# 501   93   19934       0.203140  17969.693359  Cluster 1
# 502   90   35297       0.355149  16091.402344  Cluster 1
# 503   91   20681       0.354679  18401.087891  Cluster 1
# 504   89   30267       0.289310  14386.351562  Cluster 1
#
# [505 rows x 5 columns]

# %% [markdown]
# ---
# ### **7.1.2 Evaluate Agglomerative (Hierarchical) Clustering**
# ---

# %%
evaluate_model(hierarchicalModel)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Pipeline Plot', 'pipelin…

# %% [markdown]
# ---
# ### **7.2 Density-Based Spatial Clustering**
# ---

# %%
from pycaret.datasets import get_data
from pycaret.clustering import *

jewelleryDataSet = get_data('jewellery', verbose=False)
setup(data = jewelleryDataSet, verbose=False)

# dbscan
dbscanModel = create_model('dbscan')

# did not perform well on data as all values 0
# Out:
# <style type="text/css">
# </style>
# <table id="T_a4799" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a4799_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_a4799_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_a4799_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_a4799_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_a4799_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_a4799_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a4799_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_a4799_row0_col0" class="data row0 col0" >0</td>
#       <td id="T_a4799_row0_col1" class="data row0 col1" >0</td>
#       <td id="T_a4799_row0_col2" class="data row0 col2" >0</td>
#       <td id="T_a4799_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_a4799_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_a4799_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]

# %% [markdown]
# ---
# ### **7.2.1 Assign Model - "Assign the labels" to the dataset**
# ---

# %%
dbscanModelPrediction = assign_model(dbscanModel)
dbscanModelPrediction

# Noisy samples are given the label -1 i.e. 'Cluster -1'
# Out:
#      Age  Income  SpendingScore       Savings     Cluster
# 0     58   77769       0.791329   6559.830078  Cluster -1
# 1     59   81799       0.791082   5417.661621  Cluster -1
# 2     62   74751       0.702657   9258.993164  Cluster -1
# 3     59   74373       0.765680   7346.334473  Cluster -1
# 4     87   17760       0.348778  16869.507812  Cluster -1
# ..   ...     ...            ...           ...         ...
# 500   28  101206       0.387441  14936.775391  Cluster -1
# 501   93   19934       0.203140  17969.693359  Cluster -1
# 502   90   35297       0.355149  16091.402344  Cluster -1
# 503   91   20681       0.354679  18401.087891  Cluster -1
# 504   89   30267       0.289310  14386.351562  Cluster -1
#
# [505 rows x 5 columns]

# %% [markdown]
# ### **Key Points**

# %% [markdown]
# - num_clusters not required for some of the clustering Alorithms (Affinity Propagation ('ap'), Mean shift
#   clustering ('meanshift'), Density-Based Spatial Clustering ('dbscan') and OPTICS Clustering ('optics')).
# - num_clusters param for these models are automatically determined.
#
# - When fit doesn't converge in Affinity Propagation ('ap') model, all datapoints are labelled as -1.
#
# - Noisy samples are given the label -1, when using Density-Based Spatial  ('dbscan') or OPTICS Clustering ('optics').
#
# - OPTICS ('optics') clustering may take longer training times on large datasets.

# %% [markdown]
# ---
# # **8. Deploy the model on AWS**
# ---
# **<a href="https://pycaret.readthedocs.io/en/latest/api/clustering.html#pycaret.clustering.deploy_model">Click Here</a>**
